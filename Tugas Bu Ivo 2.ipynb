# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import plotly.graph_objects as go
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import colors as mcolors
from scipy.stats import linregress
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.cluster import KMeans
from tabulate import tabulate
from collections import Counter

# %%
df = pd.read_csv('Ivo Py Data.csv',sep=';')

# %%
df.head()
# Out:
#   CODE STORE2  Selling In  Selling Out  Promo Selling Out  \
# 0        013H     2307294      3913784             606937
# 1        014H     5044074      7000001             830181
# 2        016H     3358670      7086128            1731893
# 3        004H     6116137      6385587            1487028
# 4        008H     6101340      8155948            1800992
#
#    Promo Selling Out Rate  Umur Outlet (Bulan)  Total Item Transaction  \
# 0                    0.16                   36                      26
# 1                    0.12                   32                      30
# 2                    0.24                   15                      29
# 3                    0.23                   45                      32
# 4                    0.22                   45                      30
#
#    Total Transaction  Is_East  Average Selling In Per Transaction  \
# 0                  3        0                              769098
# 1                  4        0                             1261019
# 2                  4        0                              839668
# 3                  5        0                             1223227
# 4                  6        0                             1016890
#
#    Average Selling Out Per Month  Average Promo Selling Out By Period  \
# 0                         782757                                75867
# 1                        1400000                               103773
# 2                        1417226                               216487
# 3                        1277117                               185878
# 4                        1631190                               225124
#
#    Is Active  Jenis Freezer  Is Alfamart  No Time Transaction
# 0          1              1            0                   18
# 1          1              1            0                   18
# 2          1              1            0                   14
# 3          1              1            0                   15
# 4          1              1            0                   10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   CODE STORE2                          2263 non-null   object
#  1   Selling In                           2263 non-null   int64
#  2   Selling Out                          2263 non-null   int64
#  3   Promo Selling Out                    2263 non-null   int64
#  4   Promo Selling Out Rate               2263 non-null   float64
#  5   Umur Outlet (Bulan)                  2263 non-null   int64
#  6   Total Item Transaction               2263 non-null   int64
#  7   Total Transaction                    2263 non-null   int64
#  8   Is_East                              2263 non-null   int64
#  9   Average Selling In Per Transaction   2263 non-null   int64
#  10  Average Selling Out Per Month        2263 non-null   int64
#  11  Average Promo Selling Out By Period  2263 non-null   int64
#  12  Is Active                            2263 non-null   int64
#  13  Jenis Freezer                        2263 non-null   int64
#  14  Is Alfamart                          2263 non-null   int64
#  15  No Time Transaction                  2263 non-null   int64
# dtypes: float64(1), int64(14), object(1)
# memory usage: 283.0+ KB

# %%
df=df.drop(columns='CODE STORE2')

# %%
# Define the KMeans model
kmeans = KMeans(n_clusters=5, random_state=0)

# Fit the model
kmeans.fit(df)

# Get the cluster labels
df['Cluster'] = kmeans.labels_

# Show the data with cluster labels
print("Clustering Result:")
print(df.head())
print(df.tail())
# Out:
# Clustering Result:
#    Selling In  Selling Out  Promo Selling Out  Promo Selling Out Rate  \
# 0     2307294      3913784             606937                    0.16
# 1     5044074      7000001             830181                    0.12
# 2     3358670      7086128            1731893                    0.24
# 3     6116137      6385587            1487028                    0.23
# 4     6101340      8155948            1800992                    0.22
#
#    Umur Outlet (Bulan)  Total Item Transaction  Total Transaction  Is_East  \
# 0                   36                      26                  3        0
# 1                   32                      30                  4        0
# 2                   15                      29                  4        0
# 3                   45                      32                  5        0
# 4                   45                      30                  6        0
#
#    Average Selling In Per Transaction  Average Selling Out Per Month  \
# 0                              769098                         782757
# 1                             1261019                        1400000
# 2                              839668                        1417226
# 3                             1223227                        1277117
# 4                             1016890                        1631190
#
#    Average Promo Selling Out By Period  Is Active  Jenis Freezer  Is Alfamart  \
# 0                                75867          1              1            0
# 1                               103773          1              1            0
# 2                               216487          1              1            0
# 3                               185878          1              1            0
# 4                               225124          1              1            0
#
#    No Time Transaction  Cluster
# 0                   18        1
# 1                   18        4
# 2                   14        4
# 3                   15        4
# 4                   10        4
#       Selling In  Selling Out  Promo Selling Out  Promo Selling Out Rate  \
# 2258      893519      1447658             655406                    0.45
# 2259     2050931      1973333             914324                    0.46
# 2260     1181055      1044955             563333                    0.54
# 2261     1505823       711081             617297                    0.87
# 2262      714023       227027                  0                    0.00
#
#       Umur Outlet (Bulan)  Total Item Transaction  Total Transaction  Is_East  \
# 2258                   24                       7                  3        0
# 2259                   23                      11                  5        0
# 2260                   26                       8                  3        0
# 2261                    7                       6                  3        0
# 2262                    1                       5                  1        0
#
#       Average Selling In Per Transaction  Average Selling Out Per Month  \
# 2258                              297840                         289532
# 2259                              410186                         394667
# 2260                              393685                         208991
# 2261                              501941                         142216
# 2262                              714023                          45405
#
#       Average Promo Selling Out By Period  Is Active  Jenis Freezer  \
# 2258                                81926          1              0
# 2259                               114291          1              0
# 2260                                70417          1              0
# 2261                                77162          1              0
# 2262                                    0          1              0
#
#       Is Alfamart  No Time Transaction  Cluster
# 2258            1                    2        0
# 2259            1                    3        3
# 2260            1                    4        0
# 2261            1                    2        0
# 2262            1                   12        0
#   File "C:\Users\asust\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\asust\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\asust\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\asust\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
# Display the clustering results
cluster_means_transposed = df.groupby('Cluster').mean().round(0).transpose()

print(cluster_means_transposed)
# Out:
# Cluster                                      0          1           2  \
# Selling In                           1275041.0  3659994.0   9436140.0
# Selling Out                           917100.0  4175354.0  11664544.0
# Promo Selling Out                     342148.0  1059301.0   2269329.0
# Promo Selling Out Rate                     0.0        0.0         0.0
# Umur Outlet (Bulan)                       27.0       28.0        32.0
# Total Item Transaction                     8.0       20.0        27.0
# Total Transaction                          4.0        7.0        11.0
# Is_East                                    0.0        1.0         0.0
# Average Selling In Per Transaction    448869.0   719032.0   1037938.0
# Average Selling Out Per Month         185897.0   852472.0   2376890.0
# Average Promo Selling Out By Period    42768.0   132413.0    283666.0
# Is Active                                  1.0        1.0         1.0
# Jenis Freezer                              0.0        1.0         1.0
# Is Alfamart                                1.0        0.0         0.0
# No Time Transaction                       33.0       22.0        23.0
#
# Cluster                                      3          4
# Selling In                           2236362.0  5562617.0
# Selling Out                          2300576.0  6792963.0
# Promo Selling Out                     795394.0  1424381.0
# Promo Selling Out Rate                     0.0        0.0
# Umur Outlet (Bulan)                       28.0       29.0
# Total Item Transaction                    13.0       26.0
# Total Transaction                          6.0        8.0
# Is_East                                    0.0        0.0
# Average Selling In Per Transaction    497250.0   825124.0
# Average Selling Out Per Month         464235.0  1386660.0
# Average Promo Selling Out By Period    99424.0   178048.0
# Is Active                                  1.0        1.0
# Jenis Freezer                              0.0        1.0
# Is Alfamart                                1.0        0.0
# No Time Transaction                       21.0       22.0

# %%
df.to_excel('df_clean.xlsx', index=False)

# %%
cluster_means_transposed.to_excel('df_clean2.xlsx', index=False)
